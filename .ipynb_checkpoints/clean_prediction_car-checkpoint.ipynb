# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Cleaning Data

# %%
ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: D258-06D3
#
#  Directorio de C:\Users\Sergio\Documents\IA\Projects\car_prediction
#
# 06/07/2022  17:48    <DIR>          .
# 06/07/2022  17:48    <DIR>          ..
# 06/07/2022  13:48    <DIR>          .ipynb_checkpoints
# 06/07/2022  13:18                62 car_prediction.py
# 06/07/2022  11:38         2.201.879 car_price_prediction.csv
# 06/07/2022  17:20         1.730.808 clean_car_prediction.csv
# 06/07/2022  17:48            89.532 prediction_car.ipynb
#                4 archivos      4.022.281 bytes
#                3 dirs  55.608.033.280 bytes libres

# %%
data=pd.read_csv("car_price_prediction.csv")

# %%
data
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467     -          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467     -  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0                  Yes    Hybrid           3.5  186005 km        6.0
# 1                   No    Petrol             3  192000 km        6.0
# 2                   No    Petrol           1.3  200000 km        4.0
# 3                  Yes    Hybrid           2.5  168966 km        4.0
# 4                  Yes    Petrol           1.3   91901 km        4.0
# ...                ...       ...           ...        ...        ...
# 19232              Yes       CNG     2.0 Turbo  300000 km        4.0
# 19233              Yes    Petrol           2.4  161600 km        4.0
# 19234              Yes    Diesel             2  116365 km        4.0
# 19235              Yes    Diesel             2   51258 km        4.0
# 19236              Yes    Hybrid           2.4  186923 km        4.0
#
#       Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0         Automatic          4x4  04-May        Left wheel  Silver       12
# 1         Tiptronic          4x4  04-May        Left wheel   Black        8
# 2          Variator        Front  04-May  Right-hand drive   Black        2
# 3         Automatic          4x4  04-May        Left wheel   White        0
# 4         Automatic        Front  04-May        Left wheel  Silver        4
# ...             ...          ...     ...               ...     ...      ...
# 19232        Manual         Rear  02-Mar        Left wheel  Silver        5
# 19233     Tiptronic        Front  04-May        Left wheel     Red        8
# 19234     Automatic        Front  04-May        Left wheel    Grey        4
# 19235     Automatic        Front  04-May        Left wheel   Black        4
# 19236     Automatic        Front  04-May        Left wheel   White       12
#
# [19237 rows x 18 columns]

# %%
data[['Price']]
# Out:
#        Price
# 0      13328
# 1      16621
# 2       8467
# 3       3607
# 4      11726
# ...      ...
# 19232   8467
# 19233  15681
# 19234  26108
# 19235   5331
# 19236    470
#
# [19237 rows x 1 columns]

# %%
data.describe()
# Out:
#                  ID         Price    Prod. year     Cylinders       Airbags
# count  1.923700e+04  1.923700e+04  19237.000000  19237.000000  19237.000000
# mean   4.557654e+07  1.855593e+04   2010.912824      4.582991      6.582627
# std    9.365914e+05  1.905813e+05      5.668673      1.199933      4.320168
# min    2.074688e+07  1.000000e+00   1939.000000      1.000000      0.000000
# 25%    4.569837e+07  5.331000e+03   2009.000000      4.000000      4.000000
# 50%    4.577231e+07  1.317200e+04   2012.000000      4.000000      6.000000
# 75%    4.580204e+07  2.207500e+04   2015.000000      4.000000     12.000000
# max    4.581665e+07  2.630750e+07   2020.000000     16.000000     16.000000

# %%
data.dtypes
# Out:
# ID                    int64
# Price                 int64
# Levy                 object
# Manufacturer         object
# Model                object
# Prod. year            int64
# Category             object
# Leather interior     object
# Fuel type            object
# Engine volume        object
# Mileage              object
# Cylinders           float64
# Gear box type        object
# Drive wheels         object
# Doors                object
# Wheel                object
# Color                object
# Airbags               int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
len(data)
# Out:
# 19237

# %%
data=data.dropna(how='any')

# %%
len(data)
# Out:
# 19237

# %%
#Cuantos guines hay
data.isin(['-']).sum()
# Out:
# ID                     0
# Price                  0
# Levy                5819
# Manufacturer           0
# Model                  0
# Prod. year             0
# Category               0
# Leather interior       0
# Fuel type              0
# Engine volume          0
# Mileage                0
# Cylinders              0
# Gear box type          0
# Drive wheels           0
# Doors                  0
# Wheel                  0
# Color                  0
# Airbags                0
# dtype: int64

# %%
#Indices de los guiones
val=data[data['Levy']=='-'].index
val
# Out:
# Int64Index([    2,     9,    11,    12,    23,    24,    25,    27,    32,
#                34,
#             ...
#             19205, 19218, 19219, 19220, 19221, 19223, 19224, 19226, 19229,
#             19232],
#            dtype='int64', length=5819)

# %%
#elimiando datos con los indices de antes
data_aux=data
data_aux=data_aux.drop(val)

# %%
data_aux
# Out:
#              ID  Price  Levy   Manufacturer     Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS    RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET   Equinox        2011       Jeep
# 3      45769185   3607   862           FORD    Escape        2011       Jeep
# 4      45809263  11726   446          HONDA       FIT        2014  Hatchback
# 5      45802912  39493   891        HYUNDAI  Santa FE        2016       Jeep
# ...         ...    ...   ...            ...       ...         ...        ...
# 19231  45772306   5802  1055  MERCEDES-BENZ     E 350        2013      Sedan
# 19233  45778856  15681   831        HYUNDAI    Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI    Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET   Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI    Sonata        2012      Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0                  Yes    Hybrid           3.5  186005 km        6.0
# 1                   No    Petrol             3  192000 km        6.0
# 3                  Yes    Hybrid           2.5  168966 km        4.0
# 4                  Yes    Petrol           1.3   91901 km        4.0
# 5                  Yes    Diesel             2  160931 km        4.0
# ...                ...       ...           ...        ...        ...
# 19231              Yes    Diesel           3.5  107800 km        6.0
# 19233              Yes    Petrol           2.4  161600 km        4.0
# 19234              Yes    Diesel             2  116365 km        4.0
# 19235              Yes    Diesel             2   51258 km        4.0
# 19236              Yes    Hybrid           2.4  186923 km        4.0
#
#       Gear box type Drive wheels   Doors       Wheel   Color  Airbags
# 0         Automatic          4x4  04-May  Left wheel  Silver       12
# 1         Tiptronic          4x4  04-May  Left wheel   Black        8
# 3         Automatic          4x4  04-May  Left wheel   White        0
# 4         Automatic        Front  04-May  Left wheel  Silver        4
# 5         Automatic        Front  04-May  Left wheel   White        4
# ...             ...          ...     ...         ...     ...      ...
# 19231     Automatic         Rear  04-May  Left wheel    Grey       12
# 19233     Tiptronic        Front  04-May  Left wheel     Red        8
# 19234     Automatic        Front  04-May  Left wheel    Grey        4
# 19235     Automatic        Front  04-May  Left wheel   Black        4
# 19236     Automatic        Front  04-May  Left wheel   White       12
#
# [13418 rows x 18 columns]

# %%
data_aux['Levy']=data_aux['Levy'].astype('int64')

# %%
mean_levy=int(data_aux['Levy'].mean())
mean_levy
# Out:
# 906

# %%
data['Levy']=data['Levy'].replace("-",mean_levy)

# %%
data
# Out:
#              ID  Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      45654403  13328  1399          LEXUS   RX 450        2010       Jeep
# 1      44731507  16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2      45774419   8467   906          HONDA      FIT        2006  Hatchback
# 3      45769185   3607   862           FORD   Escape        2011       Jeep
# 4      45809263  11726   446          HONDA      FIT        2014  Hatchback
# ...         ...    ...   ...            ...      ...         ...        ...
# 19232  45798355   8467   906  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  45778856  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  45804997  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235  45793526   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236  45813273    470   753        HYUNDAI   Sonata        2012      Sedan
#
#       Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0                  Yes    Hybrid           3.5  186005 km        6.0
# 1                   No    Petrol             3  192000 km        6.0
# 2                   No    Petrol           1.3  200000 km        4.0
# 3                  Yes    Hybrid           2.5  168966 km        4.0
# 4                  Yes    Petrol           1.3   91901 km        4.0
# ...                ...       ...           ...        ...        ...
# 19232              Yes       CNG     2.0 Turbo  300000 km        4.0
# 19233              Yes    Petrol           2.4  161600 km        4.0
# 19234              Yes    Diesel             2  116365 km        4.0
# 19235              Yes    Diesel             2   51258 km        4.0
# 19236              Yes    Hybrid           2.4  186923 km        4.0
#
#       Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0         Automatic          4x4  04-May        Left wheel  Silver       12
# 1         Tiptronic          4x4  04-May        Left wheel   Black        8
# 2          Variator        Front  04-May  Right-hand drive   Black        2
# 3         Automatic          4x4  04-May        Left wheel   White        0
# 4         Automatic        Front  04-May        Left wheel  Silver        4
# ...             ...          ...     ...               ...     ...      ...
# 19232        Manual         Rear  02-Mar        Left wheel  Silver        5
# 19233     Tiptronic        Front  04-May        Left wheel     Red        8
# 19234     Automatic        Front  04-May        Left wheel    Grey        4
# 19235     Automatic        Front  04-May        Left wheel   Black        4
# 19236     Automatic        Front  04-May        Left wheel   White       12
#
# [19237 rows x 18 columns]

# %%
data.isin(["-"]).sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
#Eliminar datos numericos con letras ejmplo: '2.0 Turbo'

# data_aux['Engine volume']=data['Engine volume'].str.extract('([a-zA-Z]+)')
# indice=data_aux[data_aux['Engine volume']=='Turbo'].index
# indice

# %%
data['Levy']=data['Levy'].astype('int64')
data=data.drop(['ID','Engine volume','Doors','Wheel'],axis=1)

# %%
data.dtypes
# Out:
# Price                 int64
# Levy                  int64
# Manufacturer         object
# Model                object
# Prod. year            int64
# Category             object
# Leather interior     object
# Fuel type            object
# Mileage              object
# Cylinders           float64
# Gear box type        object
# Drive wheels         object
# Color                object
# Airbags               int64
# dtype: object

# %%
data.to_csv("clean_car_prediction.csv")

# %% [markdown]
# ## Exploring information

# %%
data.describe()
# Out:
#               Price          Levy    Prod. year     Cylinders       Airbags
# count  1.923700e+04  19237.000000  19237.000000  19237.000000  19237.000000
# mean   1.855593e+04    906.584603   2010.912824      4.582991      6.582627
# std    1.905813e+05    385.733647      5.668673      1.199933      4.320168
# min    1.000000e+00     87.000000   1939.000000      1.000000      0.000000
# 25%    5.331000e+03    730.000000   2009.000000      4.000000      4.000000
# 50%    1.317200e+04    906.000000   2012.000000      4.000000      6.000000
# 75%    2.207500e+04    917.000000   2015.000000      4.000000     12.000000
# max    2.630750e+07  11714.000000   2020.000000     16.000000     16.000000

# %%
data
# Out:
#        Price  Levy   Manufacturer    Model  Prod. year   Category  \
# 0      13328  1399          LEXUS   RX 450        2010       Jeep
# 1      16621  1018      CHEVROLET  Equinox        2011       Jeep
# 2       8467   906          HONDA      FIT        2006  Hatchback
# 3       3607   862           FORD   Escape        2011       Jeep
# 4      11726   446          HONDA      FIT        2014  Hatchback
# ...      ...   ...            ...      ...         ...        ...
# 19232   8467   906  MERCEDES-BENZ  CLK 200        1999      Coupe
# 19233  15681   831        HYUNDAI   Sonata        2011      Sedan
# 19234  26108   836        HYUNDAI   Tucson        2010       Jeep
# 19235   5331  1288      CHEVROLET  Captiva        2007       Jeep
# 19236    470   753        HYUNDAI   Sonata        2012      Sedan
#
#       Leather interior Fuel type    Mileage  Cylinders Gear box type  \
# 0                  Yes    Hybrid  186005 km        6.0     Automatic
# 1                   No    Petrol  192000 km        6.0     Tiptronic
# 2                   No    Petrol  200000 km        4.0      Variator
# 3                  Yes    Hybrid  168966 km        4.0     Automatic
# 4                  Yes    Petrol   91901 km        4.0     Automatic
# ...                ...       ...        ...        ...           ...
# 19232              Yes       CNG  300000 km        4.0        Manual
# 19233              Yes    Petrol  161600 km        4.0     Tiptronic
# 19234              Yes    Diesel  116365 km        4.0     Automatic
# 19235              Yes    Diesel   51258 km        4.0     Automatic
# 19236              Yes    Hybrid  186923 km        4.0     Automatic
#
#       Drive wheels   Color  Airbags
# 0              4x4  Silver       12
# 1              4x4   Black        8
# 2            Front   Black        2
# 3              4x4   White        0
# 4            Front  Silver        4
# ...            ...     ...      ...
# 19232         Rear  Silver        5
# 19233        Front     Red        8
# 19234        Front    Grey        4
# 19235        Front   Black        4
# 19236        Front   White       12
#
# [19237 rows x 14 columns]

# %% [markdown]
# ### Analisis Unidimensional

# %%
#Variables categoricas
data['Manufacturer'].value_counts()
# Out:
# HYUNDAI          3769
# TOYOTA           3662
# MERCEDES-BENZ    2076
# FORD             1111
# CHEVROLET        1069
#                  ...
# PONTIAC             1
# HAVAL               1
# LANCIA              1
# GREATWALL           1
# SATURN              1
# Name: Manufacturer, Length: 65, dtype: int64

# %%
data['Category'].unique()
# Out:
# array(['Jeep', 'Hatchback', 'Sedan', 'Microbus', 'Goods wagon',
#        'Universal', 'Coupe', 'Minivan', 'Cabriolet', 'Limousine',
#        'Pickup'], dtype=object)

# %%
len(data['Category'].unique())
# Out:
# 11

# %%
#Valores numericos
print((data['Cylinders'].unique()))
data['Cylinders'].hist(bins=30)
# Out:
# [ 6.  4.  8.  1. 12.  3.  2. 16.  5.  7.  9. 10. 14.]
# <AxesSubplot:>

# %%
data['Levy'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Analisis multidimensional

# %%
data['Price']
# Out:
# 0        13328
# 1        16621
# 2         8467
# 3         3607
# 4        11726
#          ...
# 19232     8467
# 19233    15681
# 19234    26108
# 19235     5331
# 19236      470
# Name: Price, Length: 19237, dtype: int64

# %%
manufacturer_vs_Price=data.groupby('Manufacturer')['Price'].mean()
manufacturer_vs_Price
# Out:
# Manufacturer
# ACURA             5910.933333
# ALFA ROMEO        9890.250000
# ASTON MARTIN     54000.000000
# AUDI             14106.545098
# BENTLEY         197574.500000
#                     ...
# VAZ               4613.583333
# VOLKSWAGEN       11640.421416
# VOLVO            10278.894737
# ZAZ               3822.500000
# სხვა             17248.500000
# Name: Price, Length: 65, dtype: float64

# %%
manufacturer_vs_Price.reset_index().sort_values(by='Price',ascending=False).iloc[0:10]
# Out:
#     Manufacturer          Price
# 29   LAMBORGHINI  872946.000000
# 4        BENTLEY  197574.500000
# 42          OPEL   73305.617128
# 14       FERRARI   66955.500000
# 31    LAND ROVER   54053.489796
# 2   ASTON MARTIN   54000.000000
# 57         TESLA   53941.000000
# 45       PORSCHE   47106.037037
# 26        JAGUAR   34408.785714
# 22        HUMMER   31210.600000

# %%
manufacturer_vs_Price.reset_index().sort_values(by='Price',ascending=False).iloc[0:20].plot(kind='bar', x='Manufacturer',y='Price',figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Manufacturer'>

# %%
# precio_vs_levy=data.groupby('Manufacturer')['Category'].count()
# precio_vs_levy
